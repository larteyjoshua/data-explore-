# %%
import pandas as pd

# %%
facidata=pd.read_csv("facilities.csv")

# %%
facidata.head()
# Out:
#         Year    Ped    Car    HGV  Bus/Mini Bus  M/cycle  Pick-up  Cycle  \
# 0  6/13/1905  423.0   85.0  106.0         177.0     16.0     45.0   28.0
# 1  6/14/1905  388.0  126.0   83.0         215.0     18.0     23.0   43.0
# 2  6/15/1905  404.0   93.0  118.0         186.0     11.0     29.0   35.0
# 3  6/16/1905  367.0   81.0   91.0         180.0     18.0     41.0   22.0
# 4  6/17/1905  488.0   95.0   87.0         232.0     21.0     34.0   40.0
#
#    Other
# 0   17.0
# 1   12.0
# 2   18.0
# 3   17.0
# 4   19.0

# %%
facidata.dtypes
# Out:
# Year             object
# Ped             float64
# Car             float64
# HGV             float64
# Bus/Mini Bus    float64
# M/cycle         float64
# Pick-up         float64
# Cycle           float64
# Other           float64
# dtype: object

# %%
facidata["Car"]
# Out:
# 0      85.0
# 1     126.0
# 2      93.0
# 3      81.0
# 4      95.0
# 5     115.0
# 6     107.0
# 7     137.0
# 8     142.0
# 9     207.0
# 10    182.0
# 11    202.0
# 12    218.0
# 13    246.0
# 14    242.0
# 15    206.0
# 16    212.0
# 17    274.0
# 18    283.0
# 19    271.0
# 20    251.0
# Name: Car, dtype: float64

# %%
facidata.mean()
# Out:
# Ped             657.142857
# Car             179.761905
# HGV             159.190476
# Bus/Mini Bus    315.285714
# M/cycle          83.238095
# Pick-up          47.000000
# Cycle            65.761905
# Other            17.380952
# dtype: float64

# %%
facidata.min()
# Out:
# Year            6/13/1905
# Ped                   367
# Car                    81
# HGV                    83
# Bus/Mini Bus          177
# M/cycle                11
# Pick-up                23
# Cycle                  22
# Other                  10
# dtype: object

# %%
facidata.max()
# Out:
# Year            7/3/1905
# Ped                  938
# Car                  283
# HGV                  270
# Bus/Mini Bus         556
# M/cycle              313
# Pick-up               76
# Cycle                111
# Other                 32
# dtype: object

# %%
facidata.sum()
# Out:
# Year            6/13/19056/14/19056/15/19056/16/19056/17/19056...
# Ped                                                         13800
# Car                                                          3775
# HGV                                                          3343
# Bus/Mini Bus                                                 6621
# M/cycle                                                      1748
# Pick-up                                                       987
# Cycle                                                        1381
# Other                                                         365
# dtype: object

# %%
import datasist as ds

# %%
ds.structdata.describe(facidata)
# Out:
# First five data points
#         Year    Ped    Car    HGV  Bus/Mini Bus  M/cycle  Pick-up  Cycle  \
# 0  6/13/1905  423.0   85.0  106.0         177.0     16.0     45.0   28.0
# 1  6/14/1905  388.0  126.0   83.0         215.0     18.0     23.0   43.0
# 2  6/15/1905  404.0   93.0  118.0         186.0     11.0     29.0   35.0
# 3  6/16/1905  367.0   81.0   91.0         180.0     18.0     41.0   22.0
# 4  6/17/1905  488.0   95.0   87.0         232.0     21.0     34.0   40.0
#
#    Other
# 0   17.0
# 1   12.0
# 2   18.0
# 3   17.0
# 4   19.0
# Last five data points
#          Year    Ped    Car    HGV  Bus/Mini Bus  M/cycle  Pick-up  Cycle  \
# 16  6/29/1905  880.0  212.0  213.0         414.0    182.0     36.0   85.0
# 17  6/30/1905  855.0  274.0  184.0         282.0    170.0     45.0  111.0
# 18   7/1/1905  938.0  283.0  193.0         466.0    192.0     53.0   92.0
# 19   7/2/1905  853.0  271.0  159.0         325.0    210.0     55.0   91.0
# ...

# %%
#Gets all categorical features
cats = ds.structdata.get_cat_feats(facidata)
cats
# Out:
# ['Year']

# %%
#Gets all numeric features
nums = ds.structdata.get_num_feats(facidata)
nums
# Out:
# ['Ped', 'Car', 'HGV', 'Bus/Mini Bus', 'M/cycle', 'Pick-up', 'Cycle', 'Other']

# %%
#Gets the unique count of all categorical features
ds.structdata.get_unique_counts(facidata)
# Out:
# <style  type="text/css" >
#     #T_96eaef36_fcf7_11e9_92a8_1c7508f84dfdrow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }</style><table id="T_96eaef36_fcf7_11e9_92a8_1c7508f84dfd" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Feature</th>        <th class="col_heading level0 col1" >Unique Count</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_96eaef36_fcf7_11e9_92a8_1c7508f84dfdlevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_96eaef36_fcf7_11e9_92a8_1c7508f84dfdrow0_col0" class="data row0 col0" >Year</td>
#                         <td id="T_96eaef36_fcf7_11e9_92a8_1c7508f84dfdrow0_col1" class="data row0 col1" >21</td>
#             </tr>
#     </tbody></table>

# %%
#Display missing values in data set
ds.structdata.display_missing(facidata)
# Out:
#        features  missing_counts  missing_percent
# 0          Year               0              0.0
# 1           Ped               0              0.0
# 2           Car               0              0.0
# 3           HGV               0              0.0
# 4  Bus/Mini Bus               0              0.0
# 5       M/cycle               0              0.0
# 6       Pick-up               0              0.0
# 7         Cycle               0              0.0
# 8         Other               0              0.0

# %%
ds.visualizations.countplot(facidata)

# %%
ds.visualizations.boxplot(data=facidata, target='')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-c35d410ed6a1> in <module>
# ...

# %%
ds.visualizations.histogram(facidata)

# %%
ds.visualizations.scatterplot(data=facidata, target='Car',separate_by='Year', fig_size=(6,6))
